# %%
from EPUtils import drawResult

# %%
mae,rsme,r2 = drawResult("./eptest/2.2/exp.json")

# %%
mae.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="6d6f525b5d324fc19aeed68bdffaa965" style="width:1400px; height:660px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_6d6f525b5d324fc19aeed68bdffaa965 = echarts.init(
#                     document.getElementById('6d6f525b5d324fc19aeed68bdffaa965'), 'white', {renderer: 'canvas'});
#                 var option_6d6f525b5d324fc19aeed68bdffaa965 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %%
rsme.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="06edc885adfb401ab716d6f66fe5d20b" style="width:1400px; height:660px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_06edc885adfb401ab716d6f66fe5d20b = echarts.init(
#                     document.getElementById('06edc885adfb401ab716d6f66fe5d20b'), 'white', {renderer: 'canvas'});
#                 var option_06edc885adfb401ab716d6f66fe5d20b = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %%
r2.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="3e691e15e418446e85e14da1963bcb6b" style="width:1400px; height:660px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_3e691e15e418446e85e14da1963bcb6b = echarts.init(
#                     document.getElementById('3e691e15e418446e85e14da1963bcb6b'), 'white', {renderer: 'canvas'});
#                 var option_3e691e15e418446e85e14da1963bcb6b = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...
